# %%
# External libraries for data processing
import numpy as np
import pandas as pd
import sklearn as sk
#To render graphs within notebook
# %matplotlib inline
import matplotlib.pyplot as plt
import joblib 
import os

# Versions of libraries
print("Numpy version: {}".format(np.__version__))
print("Pandas version: {}".format(pd.__version__))
print("Scikit version: {}".format(sk.__version__))

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import accuracy_score, classification_report
# Out:
# Numpy version: 1.24.3
# Pandas version: 1.5.3
# Scikit version: 1.3.0

# %%
from joblib import dump
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# %% [markdown]
# #### Global functions

# %%
path = "C:/Project/Data/"

# %%
def convert_to_days(duration_str):
    parts = duration_str.split(' days ')  # Split string into form ['22', '20:55:00']
    days = float(parts[0])  # Extract number of days and convert to float
    time_parts = parts[1].split(':')  # Split time part (hh:mm:ss) ['20', '55', '00']
    hours = float(time_parts[0])  # Extract hours and convert to float
    minutes = float(time_parts[1])  # Extract minutes and convert to float
    seconds = float(time_parts[2])  # Extract seconds and convert to float
    total_days = days + (hours / 24) + (minutes / (24 * 60)) + (seconds / (24 * 3600))  # Calculate total days
    return total_days

# %%
file = "hosp/admissions.csv"
full_path = path + file

df_admissions = pd.read_csv(full_path)

df_admissions['dischtime'] = pd.to_datetime(df_admissions['dischtime'], format='%d/%m/%Y %H:%M')
df_admissions['admittime'] = pd.to_datetime(df_admissions['admittime'], format='%d/%m/%Y %H:%M')

df_admittime= pd.DataFrame()
df_admittime['hadm_id'] = df_admissions['hadm_id']
df_admittime['admittime'] = df_admissions['admittime']

# %%
file = "hosp/transfers.csv"
full_path = path + file

df_transfers = pd.read_csv(full_path)

# %%
# drop dishcarged samples
df_transfers = df_transfers[df_transfers['eventtype'] != 'discharge']

# convert time to datetime
df_transfers['intime'] = pd.to_datetime(df_transfers['intime'])
df_transfers['outtime'] = pd.to_datetime(df_transfers['outtime'])

# %%
# Target variable (careunit based on transfer_id)

df_target = df_transfers.drop(columns=['subject_id', 'eventtype','hadm_id','intime','outtime'])

# %%
df_target
# Out:
#       transfer_id                                      careunit
# 26       31766090                                      Med/Surg
# 27       39182916                                      Med/Surg
# 28       33930547                                      Med/Surg
# 29       39351025                                      Medicine
# 30       37834930                                      Medicine
# ...           ...                                           ...
# 1185     31983963                                          PACU
# 1186     38367109                               Cardiac Surgery
# 1187     39362807                           Medicine/Cardiology
# 1188     38425947                           Medicine/Cardiology
# 1189     36558922  Cardiac Vascular Intensive Care Unit (CVICU)
#
# [915 rows x 2 columns]

# %% [markdown]
# # Loading pretrained transfer prediction learners

# %%
path = "C:/Users/jenni/OneDrive/Desktop/IP/target_learners/"

# %% [markdown]
# ### emar

# %%
file = "bagging_clf_emar.joblib"
full_path = path + file

bagging_clf_emar = joblib.load(full_path)

# %%
bagging_clf_emar
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(random_state=42),
#                   random_state=42)

# %% [markdown]
# ### microbiologyevents

# %%
file = "bagging_clf_microbio.joblib"
full_path = path + file

bagging_clf_microbio = joblib.load(full_path)

# %%
bagging_clf_microbio
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(criterion='entropy',
#                                                    max_leaf_nodes=1000,
#                                                    random_state=42),
#                   n_estimators=12, random_state=42)

# %% [markdown]
# ### prescriptions

# %%
file = "bagging_clf_prescriptions.joblib"
full_path = path + file

bagging_clf_prescriptions = joblib.load(full_path)

# %%
bagging_clf_prescriptions
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(criterion='entropy',
#                                                    random_state=42),
#                   random_state=42)

# %% [markdown]
# ### ingredientevents

# %%
file = "bagging_clf_ingredient.joblib"
full_path = path + file

bagging_clf_ingredient = joblib.load(full_path)

# %%
bagging_clf_ingredient
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(random_state=42),
#                   n_estimators=3, random_state=42)

# %% [markdown]
# ### inputevents

# %%
file = "bagging_clf_input.joblib"
full_path = path + file

bagging_clf_input = joblib.load(full_path)

# %%
bagging_clf_input
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(criterion='entropy',
#                                                    random_state=42),
#                   random_state=42)

# %% [markdown]
# ### procedureevents

# %%
file = "bagging_clf_procedure_events.joblib"
full_path = path + file

bagging_clf_procedure_events = joblib.load(full_path)

# %%
bagging_clf_procedure_events
# Out:
# BaggingClassifier(bootstrap=False, bootstrap_features=True,
#                   estimator=DecisionTreeClassifier(criterion='entropy',
#                                                    min_samples_leaf=2,
#                                                    random_state=42),
#                   random_state=42)

# %% [markdown]
# ## Load and preprocess evaluation data

# %%
folder_name = 'EnsembleEvaluationData'

# %% [markdown]
# ### emar

# %%
file_path = os.path.join(folder_name, 'df_emar_evaluation.csv')

df_emar = pd.read_csv(file_path)

# %%
df_emar
# Out:
#       subject_id     hadm_id        emar_id  emar_seq         poe_id  \
# 0       10015272  27993466.0    10015272-31        31    10015272-48
# 1       10020786  23488445.0    10020786-27        27    10020786-47
# 2       10020786  23488445.0    10020786-26        26    10020786-47
# 3       10021312  25020332.0    10021312-28        28    10021312-39
# 4       10004235  25970245.0    10004235-83        83   10004235-554
# ...          ...         ...            ...       ...            ...
# 7570    10035631  29276678.0  10035631-1673      1673  10035631-1997
# 7571    10035631  29276678.0  10035631-1667      1667  10035631-1997
# 7572    10035631  29276678.0  10035631-1666      1666  10035631-1997
# 7573    10037861  24540843.0   10037861-371       371   10037861-385
# 7574    10014354  28335091.0   10014354-259       259   10014354-301
#
#       pharmacy_id enter_provider_id            charttime  \
# 0      88758875.0               NaN  2137-06-13 08:36:00
# 1      82871676.0               NaN  2189-06-09 15:45:00
# 2      82871676.0               NaN  2189-06-09 15:15:00
# 3             NaN            P33K2X  2113-08-16 18:08:00
# 4             NaN            P54TSS  2196-06-14 22:50:00
# ...           ...               ...                  ...
# 7570          NaN            P52GRX  2116-03-12 06:41:00
# 7571          NaN            P52GRX  2116-03-12 02:39:00
# 7572          NaN            P52GRX  2116-03-12 02:15:00
# 7573          NaN               NaN  2117-03-17 19:00:00
# 7574          NaN               NaN  2147-04-28 17:00:00
#
#                     medication                                event_txt  \
# 0          Metoprolol Tartrate                                      NaN
# 1                     CefePIME                                      NaN
# 2                     CefePIME                                      NaN
# 3                 Lidocaine 1%                                      NaN
# 4            Magnesium Sulfate                                      NaN
# ...                        ...                                      ...
# 7570  HYDROmorphone (Dilaudid)          Administered Bolus from IV Drip
# 7571  HYDROmorphone (Dilaudid)          Administered Bolus from IV Drip
# 7572  HYDROmorphone (Dilaudid)          Administered Bolus from IV Drip
# 7573                 Midazolam         Infusion Reconciliation Not Done
# 7574                   Heparin  Stopped - Unscheduled in Other Location
#
#              scheduletime            storetime
# 0     2137-06-13 08:36:00  2137-06-13 08:36:00
# 1     2189-06-09 15:45:00  2189-06-09 17:31:00
# 2     2189-06-09 15:15:00  2189-06-09 15:15:00
# 3     2113-08-16 18:08:00  2113-08-16 18:08:00
# 4     2196-06-14 22:50:00  2196-06-14 22:51:00
# ...                   ...                  ...
# 7570  2116-03-12 06:41:00  2116-03-12 06:41:00
# 7571  2116-03-12 02:39:00  2116-03-12 02:40:00
# 7572  2116-03-12 02:15:00  2116-03-12 02:39:00
# 7573  2117-03-17 19:00:00  2117-03-17 18:33:00
# 7574  2106-09-29 00:00:00  2147-04-28 22:34:00
#
# [7575 rows x 12 columns]

# %%
# Want a df of transfer_id, careunit and predicted value

# %%
df_emar = pd.merge(df_emar, df_target[['transfer_id', 'careunit']], on='transfer_id', how='left')
target_emar = df_emar[["transfer_id", "careunit"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df_emar = pd.merge(df_emar, df_target[['transfer_id', 'careunit']], on='transfer_id', how='left')
#       2 target_emar = df_emar[["transfer_id", "careunit"]]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# --> 110     op = _MergeOperation(
#     111         left,
#     112         right,
#     113         how=how,
#     114         on=on,
#     115         left_on=left_on,
#     116         right_on=right_on,
#     117         left_index=left_index,
#     118         right_index=right_index,
#     119         sort=sort,
#     120         suffixes=suffixes,
#     121         indicator=indicator,
#     122         validate=validate,
#     123     )
#     124     return op.get_result(copy=copy)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:703, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, indicator, validate)
#     696 self._cross = cross_col
#     698 # note this function has side effects
#     699 (
#     700     self.left_join_keys,
#     701     self.right_join_keys,
#     702     self.join_names,
# --> 703 ) = self._get_merge_keys()
#     705 # validate the merge keys dtypes. We may need to coerce
#     706 # to avoid incompatible dtypes
#     707 self._maybe_coerce_merge_keys()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:1179, in _MergeOperation._get_merge_keys(self)
#    1175 if lk is not None:
#    1176     # Then we're either Hashable or a wrong-length arraylike,
#    1177     #  the latter of which will raise
#    1178     lk = cast(Hashable, lk)
# -> 1179     left_keys.append(left._get_label_or_level_values(lk))
#    1180     join_names.append(lk)
#    1181 else:
#    1182     # work-around for merge_asof(left_index=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:1850, in NDFrame._get_label_or_level_values(self, key, axis)
#    1844     values = (
#    1845         self.axes[axis]
#    1846         .get_level_values(key)  # type: ignore[assignment]
#    1847         ._values
#    1848     )
#    1849 else:
# -> 1850     raise KeyError(key)
#    1852 # Check for duplicates
#    1853 if values.ndim > 1:
#
# KeyError: 'transfer_id'

# %%
target_emar

# %% [markdown]
# #### Preprocessing

# %%
# change transfer_id to careunit

df_emar = pd.merge(df_emar, df_target[['transfer_id', 'careunit']], on='transfer_id', how='left')
df_emar.drop(columns=['transfer_id','hadm_id','charttime'], inplace=True)

# %%
data = df_emar.drop(columns=['careunit'])
target = pd.DataFrame(df_emar['careunit'])

# %%
data['delay']= data['delay'].astype(str)
data['delay']= data['delay'].apply(convert_to_days)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 data['delay']= data['delay'].astype(str)
#       2 data['delay']= data['delay'].apply(convert_to_days)
#
# NameError: name 'data' is not defined

# %% [markdown]
# #### Testing the learner

# %%
# Convert DataFrame to 1D array using ravel()
target = target.values.ravel()

# Make predictions on the testing set
y_pred_emar = bagging_clf_emar.predict(data)

# Evaluate the model
accuracy = accuracy_score(target, y_pred_emar)
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(target, y_pred_emar, zero_division=0))
# Out:
# Accuracy: 0.053417576105686385
# Classification Report:
#                                                   precision    recall  f1-score   support
#
#                                  Cardiac Surgery       0.12      0.23      0.16        48
#     Cardiac Vascular Intensive Care Unit (CVICU)       0.00      0.00      0.00         0
#                         Coronary Care Unit (CCU)       0.00      0.00      0.00         2
#                                 Discharge Lounge       0.00      0.00      0.00         0
#                             Emergency Department       0.00      0.00      0.00         2
#                 Emergency Department Observation       0.31      0.60      0.41        43
#                              Hematology/Oncology       0.00      0.00      0.00       551
#                 Hematology/Oncology Intermediate       0.00      0.00      0.00       136
#                                         Med/Surg       0.10      0.14      0.11        29
#                                     Med/Surg/GYN       0.00      0.00      0.00         4
#                                  Med/Surg/Trauma       0.03      0.03      0.03        32
#               Medical Intensive Care Unit (MICU)       0.08      0.13      0.10        46
# Medical/Surgical Intensive Care Unit (MICU/SICU)       0.00      0.00      0.00        21
#                                         Medicine       0.10      0.11      0.10       274
#                              Medicine/Cardiology       0.01      0.05      0.02        98
#                 Medicine/Cardiology Intermediate       0.00      0.00      0.00         0
#                               Neuro Intermediate       0.00      0.00      0.00         6
#                                   Neuro Stepdown       0.00      0.00      0.00         0
#  Neuro Surgical Intensive Care Unit (Neuro SICU)       0.00      0.00      0.00         0
#                                        Neurology       0.09      0.05      0.06       145
#                                             PACU       0.00      0.00      0.00        86
#                                   Surgery/Trauma       0.02      0.50      0.04         6
#              Surgical Intensive Care Unit (SICU)       0.00      0.00      0.00         0
#                                       Transplant       0.02      0.01      0.02        85
#                              Trauma SICU (TSICU)       0.00      0.00      0.00        27
#                                          Unknown       0.00      0.00      0.00         1
#                                         Vascular       0.00      0.00      0.00        99
#
#                                         accuracy                           0.05      1741
#                                        macro avg       0.03      0.07      0.04      1741
#                                     weighted avg       0.04      0.05      0.04      1741

# %%
target_emar['pred_emar'] = y_pred_emar
# Out:
# C:\Users\jenni\AppData\Local\Temp\ipykernel_33724\3894870317.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_emar['pred_emar'] = y_pred_emar

# %%
target_emar
# Out:
#       transfer_id             careunit            pred_emar
# 0      30185783.0             Medicine             Medicine
# 1      37652315.0      Med/Surg/Trauma             Medicine
# 2      37652315.0      Med/Surg/Trauma             Medicine
# 3      39739186.0           Transplant                 PACU
# 4      33747001.0                 PACU  Hematology/Oncology
# ...           ...                  ...                  ...
# 1736   39136387.0  Hematology/Oncology  Medicine/Cardiology
# 1737   39136387.0  Hematology/Oncology             Medicine
# 1738   39136387.0  Hematology/Oncology             Medicine
# 1739   39136387.0  Hematology/Oncology             Medicine
# 1740   39136387.0  Hematology/Oncology             Medicine
#
# [1741 rows x 3 columns]

# %% [markdown]
# ### microbiologyevents

# %%
folder_name = 'EnsembleEvaluationData'

# %%
file_path = os.path.join(folder_name, 'df_microbio_evaluation.csv')

df_microbio = pd.read_csv(file_path)

# %%
# Want a df of transfer_id, careunit and predicted value

# %%
df_microbio = pd.merge(df_microbio, df_target[['transfer_id', 'careunit']], on='transfer_id', how='left')
target_microbio = df_microbio[["transfer_id", "careunit"]]

# %%
target_microbio
# Out:
#      transfer_id                             careunit
# 0     35065627.0  Surgical Intensive Care Unit (SICU)
# 1     34170353.0                  Trauma SICU (TSICU)
# 2     34976513.0                  Hematology/Oncology
# 3     34976513.0                  Hematology/Oncology
# 4     32627049.0                  Medicine/Cardiology
# ..           ...                                  ...
# 178   32627049.0                  Medicine/Cardiology
# 179   32627049.0                  Medicine/Cardiology
# 180   34302052.0                            Neurology
# 181   34976513.0                  Hematology/Oncology
# 182   34976513.0                  Hematology/Oncology
#
# [183 rows x 2 columns]

# %% [markdown]
# #### Preprocessing

# %%
# change transfer_id to careunit

df_microbio = pd.merge(df_microbio, df_target[['transfer_id', 'careunit']], on='transfer_id', how='left')
df_microbio.drop(columns=['transfer_id'], inplace=True)

# %%
data = df_microbio.drop(columns=['hadm_id','careunit'])
target = pd.DataFrame(df_microbio['careunit'])

# %%
# Converting duration strings to floats

data['delay']= data['delay'].astype(str)
data['delay']= data['delay'].apply(convert_to_days)
data['days_since_admission'] = data['days_since_admission'].astype(str)
data['days_since_admission'] = data['days_since_admission'].apply(convert_to_days)

# %% [markdown]
# #### Testing the learner

# %%
# Convert DataFrame to 1D array using ravel()
target = target.values.ravel()

# Make predictions on the testing set
y_pred_microbio = bagging_clf_microbio.predict(data)

# Evaluate the model
accuracy = accuracy_score(target, y_pred_microbio)
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(target, y_pred_microbio, zero_division=0))
# Out:
# Accuracy: 0.13114754098360656
# Classification Report:
#                                                   precision    recall  f1-score   support
#
#                                  Cardiac Surgery       0.73      0.44      0.55        18
#     Cardiac Vascular Intensive Care Unit (CVICU)       0.00      0.00      0.00         2
#                         Coronary Care Unit (CCU)       0.00      0.00      0.00         0
#                                 Discharge Lounge       0.00      0.00      0.00         1
#                              Hematology/Oncology       0.08      0.04      0.05        27
#                 Hematology/Oncology Intermediate       0.67      0.33      0.44         6
#                                         Med/Surg       0.00      0.00      0.00         0
#                                     Med/Surg/GYN       0.00      0.00      0.00         0
#                                  Med/Surg/Trauma       0.04      0.60      0.08         5
#               Medical Intensive Care Unit (MICU)       0.00      0.00      0.00        10
# Medical/Surgical Intensive Care Unit (MICU/SICU)       0.00      0.00      0.00         0
#                                         Medicine       0.36      0.38      0.37        24
#                              Medicine/Cardiology       0.00      0.00      0.00        29
#                                        Neurology       0.00      0.00      0.00        48
#                                             PACU       0.00      0.00      0.00         1
#              Surgical Intensive Care Unit (SICU)       1.00      0.10      0.18        10
#                                       Transplant       0.00      0.00      0.00         0
#                              Trauma SICU (TSICU)       0.00      0.00      0.00         1
#                                         Vascular       0.00      0.00      0.00         1
#
#                                         accuracy                           0.13       183
#                                        macro avg       0.15      0.10      0.09       183
#                                     weighted avg       0.21      0.13      0.14       183

# %%
target_microbio['pred_microbio'] = y_pred_microbio
# Out:
# C:\Users\jenni\AppData\Local\Temp\ipykernel_33724\2991254751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_microbio['pred_microbio'] = y_pred_microbio

# %%
target_microbio
# Out:
#      transfer_id                             careunit  \
# 0     35065627.0  Surgical Intensive Care Unit (SICU)
# 1     34170353.0                  Trauma SICU (TSICU)
# 2     34976513.0                  Hematology/Oncology
# 3     34976513.0                  Hematology/Oncology
# 4     32627049.0                  Medicine/Cardiology
# ..           ...                                  ...
# 178   32627049.0                  Medicine/Cardiology
# 179   32627049.0                  Medicine/Cardiology
# 180   34302052.0                            Neurology
# 181   34976513.0                  Hematology/Oncology
# 182   34976513.0                  Hematology/Oncology
#
#                           pred_microbio
# 0                       Cardiac Surgery
# 1                            Transplant
# 2                       Med/Surg/Trauma
# 3                       Med/Surg/Trauma
# 4                              Med/Surg
# ..                                  ...
# 178                     Med/Surg/Trauma
# 179                     Med/Surg/Trauma
# 180  Medical Intensive Care Unit (MICU)
# 181                     Med/Surg/Trauma
# 182                     Med/Surg/Trauma
#
# [183 rows x 3 columns]

# %% [markdown]
# ### prescriptions

# %%
folder_name = 'EnsembleEvaluationData'

# %%
file_path = os.path.join(folder_name, 'df_prescriptions_evaluation.csv')

df_prescriptions = pd.read_csv(file_path)

# %%
# Want a df of transfer_id, careunit and predicted value

# %%
df_prescriptions = pd.merge(df_prescriptions, df_target[['transfer_id', 'careunit']], on='transfer_id', how='left')
target_prescriptions = df_prescriptions[["transfer_id", "careunit"]]

# %%
target_prescriptions
# Out:
#       transfer_id                            careunit
# 0      39793139.0                     Med/Surg/Trauma
# 1      31077365.0  Medical Intensive Care Unit (MICU)
# 2      31077365.0  Medical Intensive Care Unit (MICU)
# 3      34953924.0                     Cardiac Surgery
# 4      33916615.0                            Med/Surg
# ...           ...                                 ...
# 1624   38564981.0                     Cardiac Surgery
# 1625   30642078.0                            Medicine
# 1626   39544317.0                            Medicine
# 1627   30744153.0                           Neurology
# 1628   30896594.0  Medical Intensive Care Unit (MICU)
#
# [1629 rows x 2 columns]

# %% [markdown]
# #### Preprocessing

# %%
# change transfer_id to careunit

df_prescriptions = pd.merge(df_prescriptions, df_target[['transfer_id', 'careunit']], on='transfer_id', how='left')
df_prescriptions.drop(columns=['transfer_id'], inplace=True)

# %%
data = df_prescriptions.drop(columns=['hadm_id','careunit'])
target = pd.DataFrame(df_prescriptions['careunit'])

# %% [markdown]
# #### Testing the learner

# %%
# Convert DataFrame to 1D array using ravel()
target = target.values.ravel()

# Make predictions on the testing set
y_pred_prescriptions = bagging_clf_prescriptions.predict(data)

# Evaluate the model
accuracy = accuracy_score(target, y_pred_prescriptions)
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(target, y_pred_prescriptions, zero_division=0))
# Out:
# Accuracy: 0.13014119091467158
# Classification Report:
#                                                   precision    recall  f1-score   support
#
#                                  Cardiac Surgery       0.18      0.43      0.26       127
#     Cardiac Vascular Intensive Care Unit (CVICU)       0.01      0.03      0.02        32
#                         Coronary Care Unit (CCU)       0.00      0.00      0.00         0
#                                 Discharge Lounge       0.00      0.00      0.00        22
#                             Emergency Department       0.00      0.00      0.00        21
#                              Hematology/Oncology       0.10      0.06      0.07       163
#                 Hematology/Oncology Intermediate       0.00      0.00      0.00        78
#                                         Med/Surg       0.15      0.28      0.20        64
#                                     Med/Surg/GYN       0.00      0.00      0.00        14
#                                  Med/Surg/Trauma       0.13      0.08      0.10       109
#               Medical Intensive Care Unit (MICU)       0.07      0.06      0.07        93
# Medical/Surgical Intensive Care Unit (MICU/SICU)       0.00      0.00      0.00         3
#                                         Medicine       0.18      0.21      0.20       233
#                              Medicine/Cardiology       0.17      0.11      0.14       196
#                 Medicine/Cardiology Intermediate       0.00      0.00      0.00         0
#                                   Neuro Stepdown       0.00      0.00      0.00         0
#                                        Neurology       0.27      0.12      0.16       271
#                                             PACU       0.00      0.00      0.00         8
#                                       Psychiatry       0.00      0.00      0.00         2
#                                   Surgery/Trauma       0.00      0.00      0.00         0
#              Surgical Intensive Care Unit (SICU)       0.00      0.00      0.00        38
#                                       Transplant       0.05      0.06      0.05        36
#                              Trauma SICU (TSICU)       0.00      0.00      0.00        14
#                                         Vascular       0.12      0.09      0.10       105
#
#                                         accuracy                           0.13      1629
#                                        macro avg       0.06      0.06      0.06      1629
#                                     weighted avg       0.14      0.13      0.13      1629

# %%
target_prescriptions['pred_prescriptions'] = y_pred_prescriptions
# Out:
# C:\Users\jenni\AppData\Local\Temp\ipykernel_33724\259850509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_prescriptions['pred_prescriptions'] = y_pred_prescriptions

# %%
target_prescriptions
# Out:
#       transfer_id                            careunit  \
# 0      39793139.0                     Med/Surg/Trauma
# 1      31077365.0  Medical Intensive Care Unit (MICU)
# 2      31077365.0  Medical Intensive Care Unit (MICU)
# 3      34953924.0                     Cardiac Surgery
# 4      33916615.0                            Med/Surg
# ...           ...                                 ...
# 1624   38564981.0                     Cardiac Surgery
# 1625   30642078.0                            Medicine
# 1626   39544317.0                            Medicine
# 1627   30744153.0                           Neurology
# 1628   30896594.0  Medical Intensive Care Unit (MICU)
#
#                       pred_prescriptions
# 0                        Cardiac Surgery
# 1                           Med/Surg/GYN
# 2                              Neurology
# 3                    Hematology/Oncology
# 4                               Med/Surg
# ...                                  ...
# 1624  Medical Intensive Care Unit (MICU)
# 1625                     Cardiac Surgery
# 1626  Medical Intensive Care Unit (MICU)
# 1627                 Medicine/Cardiology
# 1628                            Medicine
#
# [1629 rows x 3 columns]

# %% [markdown]
# ### ingredientevents

# %%
folder_name = 'EnsembleEvaluationData'

# %%
file_path = os.path.join(folder_name, 'df_ingredient_evaluation.csv')

df_ingredient = pd.read_csv(file_path)

# %%
# Want a df of transfer_id, careunit and predicted value

# %%
df_ingredient = pd.merge(df_ingredient, df_target[['transfer_id', 'careunit']], on='transfer_id', how='left')
target_ingredient = df_ingredient[["transfer_id", "careunit"]]

# %%
target_ingredient
# Out:
#       transfer_id                          careunit
# 0      35186527.0  Hematology/Oncology Intermediate
# 1      35186527.0  Hematology/Oncology Intermediate
# 2      35186527.0  Hematology/Oncology Intermediate
# 3      35186527.0  Hematology/Oncology Intermediate
# 4      35186527.0  Hematology/Oncology Intermediate
# ...           ...                               ...
# 2516   37348935.0                         Neurology
# 2517   37348935.0                         Neurology
# 2518   37348935.0                         Neurology
# 2519   37348935.0                         Neurology
# 2520   37348935.0                         Neurology
#
# [2521 rows x 2 columns]

# %% [markdown]
# #### Preprocessing

# %%
df_ingredient = pd.merge(df_ingredient, df_target[['transfer_id', 'careunit']], on='transfer_id', how='left')
df_ingredient.drop(columns=['transfer_id'], inplace=True)
data = df_ingredient.drop(columns=['hadm_id','careunit'])
target = pd.DataFrame(df_ingredient['careunit'])

# %% [markdown]
# #### Testing the learner

# %%
# Convert DataFrame to 1D array using ravel()
target = target.values.ravel()

# Make predictions on the testing set
y_pred_ingredient = bagging_clf_ingredient.predict(data)

# Evaluate the model
accuracy = accuracy_score(target, y_pred_ingredient)
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(target, y_pred_ingredient, zero_division=0))
# Out:
# Accuracy: 0.09163030543435145
# Classification Report:
#                                                   precision    recall  f1-score   support
#
#                                  Cardiac Surgery       0.16      0.55      0.25       110
#     Cardiac Vascular Intensive Care Unit (CVICU)       0.00      0.00      0.00         0
#                         Coronary Care Unit (CCU)       0.00      0.00      0.00         0
#                              Hematology/Oncology       0.19      0.02      0.03       550
#                 Hematology/Oncology Intermediate       0.00      0.00      0.00       121
#                                         Med/Surg       0.00      0.00      0.00         0
#                                     Med/Surg/GYN       0.00      0.00      0.00         0
#                                  Med/Surg/Trauma       0.05      0.18      0.08       137
#               Medical Intensive Care Unit (MICU)       0.25      0.02      0.04       250
# Medical/Surgical Intensive Care Unit (MICU/SICU)       0.00      0.00      0.00         1
#                                         Medicine       0.06      0.46      0.10       133
#                              Medicine/Cardiology       0.20      0.29      0.24       171
#                 Medicine/Cardiology Intermediate       0.00      0.00      0.00         0
#                                        Neurology       0.75      0.02      0.04       957
#                                             PACU       0.00      0.00      0.00         0
#              Surgical Intensive Care Unit (SICU)       0.00      0.00      0.00         0
#                                       Transplant       0.00      0.00      0.00         0
#                              Trauma SICU (TSICU)       0.00      0.00      0.00         0
#                                         Vascular       0.00      0.00      0.00        91
#
#                                         accuracy                           0.09      2521
#                                        macro avg       0.09      0.08      0.04      2521
#                                     weighted avg       0.38      0.09      0.06      2521

# %%
target_ingredient['pred_ingredient'] = y_pred_ingredient
# Out:
# C:\Users\jenni\AppData\Local\Temp\ipykernel_33724\937182014.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_ingredient['pred_ingredient'] = y_pred_ingredient

# %%
target_ingredient
# Out:
#       transfer_id                          careunit      pred_ingredient
# 0      35186527.0  Hematology/Oncology Intermediate             Medicine
# 1      35186527.0  Hematology/Oncology Intermediate             Medicine
# 2      35186527.0  Hematology/Oncology Intermediate  Medicine/Cardiology
# 3      35186527.0  Hematology/Oncology Intermediate  Medicine/Cardiology
# 4      35186527.0  Hematology/Oncology Intermediate      Cardiac Surgery
# ...           ...                               ...                  ...
# 2516   37348935.0                         Neurology  Medicine/Cardiology
# 2517   37348935.0                         Neurology             Medicine
# 2518   37348935.0                         Neurology             Medicine
# 2519   37348935.0                         Neurology  Medicine/Cardiology
# 2520   37348935.0                         Neurology  Medicine/Cardiology
#
# [2521 rows x 3 columns]

# %% [markdown]
# ### inputevents

# %%
folder_name = 'EnsembleEvaluationData'

# %%
file_path = os.path.join(folder_name, 'df_input_evaluation.csv')

df_input = pd.read_csv(file_path)

# %%
# Want a df of transfer_id, careunit and predicted value

# %%
df_input = pd.merge(df_input, df_target[['transfer_id', 'careunit']], on='transfer_id', how='left')
target_input = df_input[["transfer_id", "careunit"]]

# %%
target_input
# Out:
#       transfer_id                          careunit
# 0      35186527.0  Hematology/Oncology Intermediate
# 1      35186527.0  Hematology/Oncology Intermediate
# 2      35186527.0  Hematology/Oncology Intermediate
# 3      35186527.0  Hematology/Oncology Intermediate
# 4      35186527.0  Hematology/Oncology Intermediate
# ...           ...                               ...
# 1918   37348935.0                         Neurology
# 1919   37348935.0                         Neurology
# 1920   37348935.0                         Neurology
# 1921   37348935.0                         Neurology
# 1922   37348935.0                         Neurology
#
# [1923 rows x 2 columns]

# %% [markdown]
# #### Preprocessing

# %%
# change transfer_id to careunit

df_input = pd.merge(df_input, df_target[['transfer_id', 'careunit']], on='transfer_id', how='left')
df_input.drop(columns=['transfer_id'], inplace=True)
data = df_input.drop(columns=['hadm_id','careunit'])
target = pd.DataFrame(df_input['careunit'])

# %% [markdown]
# #### Testing the learner

# %%
# Convert DataFrame to 1D array using ravel()
target = target.values.ravel()

# Make predictions on the testing set
y_pred_input = bagging_clf_input.predict(data)

# Evaluate the model
accuracy = accuracy_score(target, y_pred_input)
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(target, y_pred_input, zero_division=0))
# Out:
# Accuracy: 0.02080083203328133
# Classification Report:
#                                                   precision    recall  f1-score   support
#
#                                  Cardiac Surgery       0.00      0.00      0.00        81
#     Cardiac Vascular Intensive Care Unit (CVICU)       0.00      0.00      0.00         0
#                         Coronary Care Unit (CCU)       0.00      0.00      0.00         0
#                              Hematology/Oncology       0.00      0.00      0.00       439
#                 Hematology/Oncology Intermediate       0.00      0.00      0.00        71
#                                         Med/Surg       0.00      0.00      0.00         0
#                                     Med/Surg/GYN       0.00      0.00      0.00         0
#                                  Med/Surg/Trauma       0.00      0.00      0.00       121
#               Medical Intensive Care Unit (MICU)       0.00      0.00      0.00       177
# Medical/Surgical Intensive Care Unit (MICU/SICU)       0.00      0.00      0.00         1
#                                         Medicine       0.05      0.37      0.09       108
#                              Medicine/Cardiology       0.00      0.00      0.00       162
#                                   Neuro Stepdown       0.00      0.00      0.00         0
#                                        Neurology       0.00      0.00      0.00       688
#                                             PACU       0.00      0.00      0.00         0
#                              Trauma SICU (TSICU)       0.00      0.00      0.00         0
#                                         Vascular       0.00      0.00      0.00        75
#
#                                         accuracy                           0.02      1923
#                                        macro avg       0.00      0.02      0.01      1923
#                                     weighted avg       0.00      0.02      0.00      1923

# %%
target_input['pred_input'] = y_pred_input
# Out:
# C:\Users\jenni\AppData\Local\Temp\ipykernel_33724\2646750985.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_input['pred_input'] = y_pred_input

# %%
target_input
# Out:
#       transfer_id                          careunit           pred_input
# 0      35186527.0  Hematology/Oncology Intermediate  Medicine/Cardiology
# 1      35186527.0  Hematology/Oncology Intermediate  Medicine/Cardiology
# 2      35186527.0  Hematology/Oncology Intermediate  Medicine/Cardiology
# 3      35186527.0  Hematology/Oncology Intermediate  Medicine/Cardiology
# 4      35186527.0  Hematology/Oncology Intermediate  Medicine/Cardiology
# ...           ...                               ...                  ...
# 1918   37348935.0                         Neurology       Neuro Stepdown
# 1919   37348935.0                         Neurology       Neuro Stepdown
# 1920   37348935.0                         Neurology       Neuro Stepdown
# 1921   37348935.0                         Neurology       Neuro Stepdown
# 1922   37348935.0                         Neurology       Neuro Stepdown
#
# [1923 rows x 3 columns]

# %% [markdown]
# ### procedureevents

# %%
folder_name = 'EnsembleEvaluationData'

# %%
file_path = os.path.join(folder_name, 'df_procedure_events_evaluation.csv')

df_procedure_events = pd.read_csv(file_path)

# %%
# Want a df of transfer_id, careunit and predicted value

# %%
df_procedure_events = pd.merge(df_procedure_events, df_target[['transfer_id', 'careunit']], on='transfer_id', how='left')
target_procedure_events = df_procedure_events[["transfer_id", "careunit"]]

# %%
target_procedure_events
# Out:
#      transfer_id                          careunit
# 0     39136387.0               Hematology/Oncology
# 1     39136387.0               Hematology/Oncology
# 2     39136387.0               Hematology/Oncology
# 3     39136387.0               Hematology/Oncology
# 4     39136387.0               Hematology/Oncology
# ..           ...                               ...
# 169   37348935.0                         Neurology
# 170   37348935.0                         Neurology
# 171   35186527.0  Hematology/Oncology Intermediate
# 172   35186527.0  Hematology/Oncology Intermediate
# 173   35186527.0  Hematology/Oncology Intermediate
#
# [174 rows x 2 columns]

# %% [markdown]
# #### Preprocessing

# %%
# change transfer_id to careunit

df_procedure_events = pd.merge(df_procedure_events, df_target[['transfer_id', 'careunit']], on='transfer_id', how='left')
df_procedure_events.drop(columns=['transfer_id'], inplace=True)
data = df_procedure_events.drop(columns=['hadm_id','careunit'])
target = pd.DataFrame(df_procedure_events['careunit'])

# %% [markdown]
# #### Testing the learner

# %%
# Convert DataFrame to 1D array using ravel()
target = target.values.ravel()

# Make predictions on the testing set
y_pred_procedure_events = bagging_clf_procedure_events.predict(data)

# Evaluate the model
accuracy = accuracy_score(target, y_pred_procedure_events)
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(target, y_pred_procedure_events, zero_division=0))
# Out:
# Accuracy: 0.017241379310344827
# Classification Report:
#                                                   precision    recall  f1-score   support
#
#                                  Cardiac Surgery       0.00      0.00      0.00        12
#                              Hematology/Oncology       0.00      0.00      0.00        24
#                 Hematology/Oncology Intermediate       0.00      0.00      0.00         7
#                                         Med/Surg       0.00      0.00      0.00         0
#                                     Med/Surg/GYN       0.00      0.00      0.00         0
#                                  Med/Surg/Trauma       0.00      0.00      0.00        16
#               Medical Intensive Care Unit (MICU)       0.00      0.00      0.00         5
# Medical/Surgical Intensive Care Unit (MICU/SICU)       0.00      0.00      0.00         0
#                                         Medicine       0.25      0.15      0.19        20
#                              Medicine/Cardiology       0.00      0.00      0.00        23
#                                   Neuro Stepdown       0.00      0.00      0.00         0
#                                        Neurology       0.00      0.00      0.00        64
#                                             PACU       0.00      0.00      0.00         0
#                                       Transplant       0.00      0.00      0.00         0
#                              Trauma SICU (TSICU)       0.00      0.00      0.00         0
#                                         Vascular       0.00      0.00      0.00         3
#
#                                         accuracy                           0.02       174
#                                        macro avg       0.02      0.01      0.01       174
#                                     weighted avg       0.03      0.02      0.02       174

# %%
target_procedure_events['pred_procedure_events'] = y_pred_procedure_events
# Out:
# C:\Users\jenni\AppData\Local\Temp\ipykernel_33724\260886142.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   target_procedure_events['pred_procedure_events'] = y_pred_procedure_events

# %%
target_procedure_events
# Out:
#      transfer_id                          careunit  \
# 0     39136387.0               Hematology/Oncology
# 1     39136387.0               Hematology/Oncology
# 2     39136387.0               Hematology/Oncology
# 3     39136387.0               Hematology/Oncology
# 4     39136387.0               Hematology/Oncology
# ..           ...                               ...
# 169   37348935.0                         Neurology
# 170   37348935.0                         Neurology
# 171   35186527.0  Hematology/Oncology Intermediate
# 172   35186527.0  Hematology/Oncology Intermediate
# 173   35186527.0  Hematology/Oncology Intermediate
#
#                                 pred_procedure_events
# 0    Medical/Surgical Intensive Care Unit (MICU/SICU)
# 1    Medical/Surgical Intensive Care Unit (MICU/SICU)
# 2    Medical/Surgical Intensive Care Unit (MICU/SICU)
# 3    Medical/Surgical Intensive Care Unit (MICU/SICU)
# 4    Medical/Surgical Intensive Care Unit (MICU/SICU)
# ..                                                ...
# 169                                    Neuro Stepdown
# 170                                    Neuro Stepdown
# 171                                          Medicine
# 172                                          Medicine
# 173                                          Medicine
#
# [174 rows x 3 columns]

# %%
# Can see which units get commonly confused

# %%
pd.DataFrame(target).value_counts()
# Out:
# Neurology                             64
# Hematology/Oncology                   24
# Medicine/Cardiology                   23
# Medicine                              20
# Med/Surg/Trauma                       16
# Cardiac Surgery                       12
# Hematology/Oncology Intermediate       7
# Medical Intensive Care Unit (MICU)     5
# Vascular                               3
# dtype: int64

# %%
pd.DataFrame(y_pred_procedure_events).value_counts()
# Out:
# Medical/Surgical Intensive Care Unit (MICU/SICU)    47
# Transplant                                          40
# Med/Surg/Trauma                                     21
# Neuro Stepdown                                      17
# Med/Surg                                            15
# Medicine                                            12
# PACU                                                 7
# Medical Intensive Care Unit (MICU)                   5
# Hematology/Oncology                                  4
# Med/Surg/GYN                                         3
# Medicine/Cardiology                                  2
# Trauma SICU (TSICU)                                  1
# dtype: int64

# %% [markdown]
# ## Combining predictions

# %%
target_input
# Out:
# 0   transfer_id                                        pred_input  \
# 0    30281852.0                                   Med/Surg/Trauma
# 1    30896594.0                                          Medicine
# 2    31026953.0      Cardiac Vascular Intensive Care Unit (CVICU)
# 3    32051325.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 4    32537286.0                Medical Intensive Care Unit (MICU)
# 5    32627049.0                                          Medicine
# 6    32787491.0                                              PACU
# 7    32832189.0                                    Neuro Stepdown
# 8    32932646.0                               Trauma SICU (TSICU)
# 9    33281088.0                                          Medicine
# 10   34302052.0                                          Medicine
# 11   34372637.0                                      Med/Surg/GYN
# 12   35186527.0                               Medicine/Cardiology
# 13   36412172.0                                          Med/Surg
# 14   37348935.0                                    Neuro Stepdown
# 15   37509207.0                                          Medicine
# 16   37652315.0                                    Neuro Stepdown
# 17   38228591.0                               Hematology/Oncology
# 18   39136387.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 19   39429848.0                                   Cardiac Surgery
# 20   39544317.0                                          Medicine
# 21   39793139.0                               Hematology/Oncology
#
# 0                                            y_input
# 0                                          Neurology
# 1                 Medical Intensive Care Unit (MICU)
# 2                                          Neurology
# 3                                    Cardiac Surgery
# 4                                           Medicine
# 5                                Medicine/Cardiology
# 6                                           Medicine
# 7                                          Neurology
# 8                                           Vascular
# 9   Medical/Surgical Intensive Care Unit (MICU/SICU)
# 10                                         Neurology
# 11                                          Medicine
# 12                  Hematology/Oncology Intermediate
# 13                                          Medicine
# 14                                         Neurology
# 15                                          Vascular
# 16                                   Med/Surg/Trauma
# 17                               Medicine/Cardiology
# 18                               Hematology/Oncology
# 19                  Hematology/Oncology Intermediate
# 20                                          Medicine
# 21                                   Med/Surg/Trauma

# %%
target_input = target_input.rename(columns={'careunit': 'y_input'})

# %%
target_procedure_events = target_procedure_events.rename(columns={'careunit': 'y_procedure_events'})

# %%
target_procedure_events
# Out:
# 0   transfer_id                             pred_procedure_events  \
# 0    30281852.0                                   Med/Surg/Trauma
# 1    30896594.0                                          Medicine
# 2    31026953.0                                   Med/Surg/Trauma
# 3    32051325.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 4    32537286.0                Medical Intensive Care Unit (MICU)
# 5    32627049.0                                        Transplant
# 6    32787491.0                                              PACU
# 7    32832189.0                                    Neuro Stepdown
# 8    34302052.0                                        Transplant
# 9    34372637.0                                      Med/Surg/GYN
# 10   35186527.0                                          Medicine
# 11   36412172.0                                          Med/Surg
# 12   37348935.0                                    Neuro Stepdown
# 13   37509207.0                                          Med/Surg
# 14   37652315.0                                    Neuro Stepdown
# 15   38228591.0                               Hematology/Oncology
# 16   39136387.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 17   39429848.0                Medical Intensive Care Unit (MICU)
# 18   39544317.0                                          Medicine
# 19   39793139.0                                          Med/Surg
#
# 0                   y_procedure_events
# 0                            Neurology
# 1   Medical Intensive Care Unit (MICU)
# 2                            Neurology
# 3                      Cardiac Surgery
# 4                             Medicine
# 5                  Medicine/Cardiology
# 6                             Medicine
# 7                            Neurology
# 8                            Neurology
# 9                             Medicine
# 10    Hematology/Oncology Intermediate
# 11                            Medicine
# 12                           Neurology
# 13                            Vascular
# 14                     Med/Surg/Trauma
# 15                 Medicine/Cardiology
# 16                 Hematology/Oncology
# 17    Hematology/Oncology Intermediate
# 18                            Medicine
# 19                     Med/Surg/Trauma

# %%
target_microbio = target_microbio.rename(columns={'careunit': 'y_microbio'})

# %%
target_microbio
# Out:
# 0   transfer_id                                     pred_microbio  \
# 0    30281852.0                                          Med/Surg
# 1    30642078.0                                   Med/Surg/Trauma
# 2    30896594.0                                      Med/Surg/GYN
# 3    31077365.0                               Hematology/Oncology
# 4    31983963.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 5    32537286.0                                   Med/Surg/Trauma
# 6    32627049.0                                   Med/Surg/Trauma
# 7    32787491.0                                          Medicine
# 8    32832189.0                                   Med/Surg/Trauma
# 9    33082827.0                                          Med/Surg
# 10   34170353.0                                        Transplant
# 11   34302052.0                Medical Intensive Care Unit (MICU)
# 12   34372637.0                                          Medicine
# 13   34953924.0                                   Cardiac Surgery
# 14   34976513.0                                   Med/Surg/Trauma
# 15   35065627.0                                          Medicine
# 16   35186527.0                  Hematology/Oncology Intermediate
# 17   35258379.0                                          Medicine
# 18   36412172.0      Cardiac Vascular Intensive Care Unit (CVICU)
# 19   37509207.0                                          Medicine
# 20   37665491.0                                          Medicine
# 21   37921160.0                                   Med/Surg/Trauma
# 22   38369052.0                               Trauma SICU (TSICU)
# 23   38430513.0                                   Med/Surg/Trauma
# 24   39136387.0                                   Med/Surg/Trauma
# 25   39429848.0                                          Medicine
# 26   39544317.0                                   Cardiac Surgery
# 27   39793139.0                                   Med/Surg/Trauma
#
# 0                                     y_microbio
# 0                                      Neurology
# 1                                       Medicine
# 2             Medical Intensive Care Unit (MICU)
# 3             Medical Intensive Care Unit (MICU)
# 4                                           PACU
# 5                                       Medicine
# 6                            Medicine/Cardiology
# 7                                       Medicine
# 8                                      Neurology
# 9                                Cardiac Surgery
# 10                           Trauma SICU (TSICU)
# 11                                     Neurology
# 12                                      Medicine
# 13                               Cardiac Surgery
# 14                           Hematology/Oncology
# 15           Surgical Intensive Care Unit (SICU)
# 16              Hematology/Oncology Intermediate
# 17  Cardiac Vascular Intensive Care Unit (CVICU)
# 18                                      Medicine
# 19                                      Vascular
# 20                                      Medicine
# 21                               Med/Surg/Trauma
# 22                              Discharge Lounge
# 23            Medical Intensive Care Unit (MICU)
# 24                           Hematology/Oncology
# 25              Hematology/Oncology Intermediate
# 26                                      Medicine
# 27                               Med/Surg/Trauma

# %%
target_ingredient = target_ingredient.rename(columns={'careunit': 'y_ingredient'})

# %%
target_ingredient
# Out:
# 0   transfer_id      pred_ingredient  \
# 0    30281852.0             Medicine
# 1    30896594.0             Medicine
# 2    31026953.0  Medicine/Cardiology
# 3    32051325.0      Cardiac Surgery
# 4    32537286.0             Medicine
# 5    32627049.0             Medicine
# 6    32787491.0             Medicine
# 7    32832189.0             Medicine
# 8    32932646.0             Medicine
# 9    33281088.0      Cardiac Surgery
# 10   34302052.0             Medicine
# 11   34372637.0             Medicine
# 12   35186527.0  Medicine/Cardiology
# 13   36412172.0         Med/Surg/GYN
# 14   37348935.0  Medicine/Cardiology
# 15   37509207.0             Medicine
# 16   37652315.0             Medicine
# 17   38228591.0             Medicine
# 18   39136387.0             Medicine
# 19   39429848.0  Medicine/Cardiology
# 20   39544317.0             Medicine
# 21   39793139.0             Medicine
#
# 0                                       y_ingredient
# 0                                          Neurology
# 1                 Medical Intensive Care Unit (MICU)
# 2                                          Neurology
# 3                                    Cardiac Surgery
# 4                                           Medicine
# 5                                Medicine/Cardiology
# 6                                           Medicine
# 7                                          Neurology
# 8                                           Vascular
# 9   Medical/Surgical Intensive Care Unit (MICU/SICU)
# 10                                         Neurology
# 11                                          Medicine
# 12                  Hematology/Oncology Intermediate
# 13                                          Medicine
# 14                                         Neurology
# 15                                          Vascular
# 16                                   Med/Surg/Trauma
# 17                               Medicine/Cardiology
# 18                               Hematology/Oncology
# 19                  Hematology/Oncology Intermediate
# 20                                          Medicine
# 21                                   Med/Surg/Trauma

# %%
target_prescriptions = target_prescriptions.rename(columns={'careunit': 'y_prescriptions'})

# %%
target_prescriptions
# Out:
# 0   transfer_id                            pred_prescriptions  \
# 0    30145190.0  Cardiac Vascular Intensive Care Unit (CVICU)
# 1    30185783.0                               Cardiac Surgery
# 2    30265082.0                           Hematology/Oncology
# 3    30281852.0                                      Medicine
# 4    30642078.0                               Cardiac Surgery
# ..          ...                                           ...
# 67   39544317.0                                      Med/Surg
# 68   39641848.0                                      Medicine
# 69   39670756.0            Medical Intensive Care Unit (MICU)
# 70   39764235.0                                      Med/Surg
# 71   39793139.0                               Cardiac Surgery
#
# 0        y_prescriptions
# 0              Neurology
# 1               Medicine
# 2    Hematology/Oncology
# 3              Neurology
# 4               Medicine
# ..                   ...
# 67              Medicine
# 68            Transplant
# 69   Hematology/Oncology
# 70  Emergency Department
# 71       Med/Surg/Trauma
#
# [72 rows x 3 columns]

# %%
target_emar = target_emar.rename(columns={'careunit': 'y_emar'})

# %%
target_emar
# Out:
# 0   transfer_id                                         pred_emar  \
# 0    30145190.0                          Coronary Care Unit (CCU)
# 1    30145612.0                                          Medicine
# 2    30185783.0                                      Med/Surg/GYN
# 3    30458338.0                                          Medicine
# 4    30619804.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 5    30642078.0                               Hematology/Oncology
# 6    30744153.0                                          Medicine
# 7    31043383.0                               Trauma SICU (TSICU)
# 8    31077365.0                               Hematology/Oncology
# 9    31306648.0                               Medicine/Cardiology
# 10   31320729.0                               Medicine/Cardiology
# 11   31373193.0                                              PACU
# 12   31503280.0                               Hematology/Oncology
# 13   31582912.0                                          Medicine
# 14   31594060.0                               Hematology/Oncology
# 15   31715741.0                  Medicine/Cardiology Intermediate
# 16   31983963.0                               Medicine/Cardiology
# 17   32051325.0                                   Cardiac Surgery
# 18   32131502.0                               Medicine/Cardiology
# 19   32537286.0                                      Med/Surg/GYN
# 20   32537287.0                                          Medicine
# 21   32554129.0                                   Cardiac Surgery
# 22   32660091.0                               Hematology/Oncology
# 23   32732194.0                                          Medicine
# 24   32832189.0                                          Medicine
# 25   32932646.0                                   Med/Surg/Trauma
# 26   33281088.0                                   Cardiac Surgery
# 27   33747001.0                               Hematology/Oncology
# 28   33915179.0                               Medicine/Cardiology
# 29   33994907.0                                          Vascular
# 30   34107647.0                                          Medicine
# 31   34170353.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 32   34392585.0                                   Cardiac Surgery
# 33   34503142.0                                          Med/Surg
# 34   35044342.0                               Medicine/Cardiology
# 35   35186527.0                               Medicine/Cardiology
# 36   35485831.0                  Emergency Department Observation
# 37   35509340.0                                              PACU
# 38   35727289.0                                          Medicine
# 39   35921271.0   Neuro Surgical Intensive Care Unit (Neuro SICU)
# 40   36059427.0                Medical Intensive Care Unit (MICU)
# 41   36190790.0                                          Medicine
# 42   36974713.0                                          Medicine
# 43   37348935.0                Medical Intensive Care Unit (MICU)
# 44   37460777.0                               Medicine/Cardiology
# 45   37652315.0                                   Cardiac Surgery
# 46   37738145.0                               Medicine/Cardiology
# 47   38228591.0                                         Neurology
# 48   38430513.0                                        Transplant
# 49   38598607.0                                          Vascular
# 50   39136387.0                               Medicine/Cardiology
# 51   39257822.0                                   Cardiac Surgery
# 52   39429848.0                                          Medicine
# 53   39641848.0                                          Medicine
# 54   39739186.0                                              PACU
#
# 0                                             y_emar
# 0                                          Neurology
# 1                                           Medicine
# 2                                           Medicine
# 3                   Hematology/Oncology Intermediate
# 4                                           Med/Surg
# 5                                           Medicine
# 6                                          Neurology
# 7                                Medicine/Cardiology
# 8                 Medical Intensive Care Unit (MICU)
# 9                                           Medicine
# 10                  Emergency Department Observation
# 11                                    Surgery/Trauma
# 12                                          Med/Surg
# 13                                         Neurology
# 14                  Emergency Department Observation
# 15                                          Medicine
# 16                                              PACU
# 17                                   Cardiac Surgery
# 18                                          Vascular
# 19                                          Medicine
# 20                              Emergency Department
# 21                                Neuro Intermediate
# 22                  Emergency Department Observation
# 23                                              PACU
# 24                                         Neurology
# 25                                          Vascular
# 26  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 27                                              PACU
# 28                                           Unknown
# 29                  Hematology/Oncology Intermediate
# 30  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 31                               Trauma SICU (TSICU)
# 32                                   Med/Surg/Trauma
# 33                  Emergency Department Observation
# 34  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 35                  Hematology/Oncology Intermediate
# 36                  Emergency Department Observation
# 37                                        Transplant
# 38  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 39                                          Medicine
# 40                          Coronary Care Unit (CCU)
# 41                                         Neurology
# 42                                      Med/Surg/GYN
# 43                                         Neurology
# 44                                          Med/Surg
# 45                                   Med/Surg/Trauma
# 46                                          Vascular
# 47                               Medicine/Cardiology
# 48                Medical Intensive Care Unit (MICU)
# 49                  Emergency Department Observation
# 50                               Hematology/Oncology
# 51                                          Medicine
# 52                  Hematology/Oncology Intermediate
# 53                                        Transplant
# 54                                        Transplant

# %%
# Change individual prediction tables so they predict once per transfer_id (just take the majority vote)
# Group by id and take vote using mode

# %%
target_input = target_input.groupby('transfer_id')[['pred_input','careunit']].apply(lambda x: x.mode().iloc[0]).reset_index()

# %%
target_input
# Out:
# 0   transfer_id                                        pred_input  \
# 0    30281852.0                                   Med/Surg/Trauma
# 1    30896594.0                                          Medicine
# 2    31026953.0      Cardiac Vascular Intensive Care Unit (CVICU)
# 3    32051325.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 4    32537286.0                Medical Intensive Care Unit (MICU)
# 5    32627049.0                                          Medicine
# 6    32787491.0                                              PACU
# 7    32832189.0                                    Neuro Stepdown
# 8    32932646.0                               Trauma SICU (TSICU)
# 9    33281088.0                                          Medicine
# 10   34302052.0                                          Medicine
# 11   34372637.0                                      Med/Surg/GYN
# 12   35186527.0                               Medicine/Cardiology
# 13   36412172.0                                          Med/Surg
# 14   37348935.0                                    Neuro Stepdown
# 15   37509207.0                                          Medicine
# 16   37652315.0                                    Neuro Stepdown
# 17   38228591.0                               Hematology/Oncology
# 18   39136387.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 19   39429848.0                                   Cardiac Surgery
# 20   39544317.0                                          Medicine
# 21   39793139.0                               Hematology/Oncology
#
# 0                                           careunit
# 0                                          Neurology
# 1                 Medical Intensive Care Unit (MICU)
# 2                                          Neurology
# 3                                    Cardiac Surgery
# 4                                           Medicine
# 5                                Medicine/Cardiology
# 6                                           Medicine
# 7                                          Neurology
# 8                                           Vascular
# 9   Medical/Surgical Intensive Care Unit (MICU/SICU)
# 10                                         Neurology
# 11                                          Medicine
# 12                  Hematology/Oncology Intermediate
# 13                                          Medicine
# 14                                         Neurology
# 15                                          Vascular
# 16                                   Med/Surg/Trauma
# 17                               Medicine/Cardiology
# 18                               Hematology/Oncology
# 19                  Hematology/Oncology Intermediate
# 20                                          Medicine
# 21                                   Med/Surg/Trauma

# %%
target_procedure_events = target_procedure_events.groupby('transfer_id')[['pred_procedure_events','careunit']].apply(lambda x: x.mode().iloc[0]).reset_index()

# %%
target_procedure_events
# Out:
# 0   transfer_id                             pred_procedure_events  \
# 0    30281852.0                                   Med/Surg/Trauma
# 1    30896594.0                                          Medicine
# 2    31026953.0                                   Med/Surg/Trauma
# 3    32051325.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 4    32537286.0                Medical Intensive Care Unit (MICU)
# 5    32627049.0                                        Transplant
# 6    32787491.0                                              PACU
# 7    32832189.0                                    Neuro Stepdown
# 8    34302052.0                                        Transplant
# 9    34372637.0                                      Med/Surg/GYN
# 10   35186527.0                                          Medicine
# 11   36412172.0                                          Med/Surg
# 12   37348935.0                                    Neuro Stepdown
# 13   37509207.0                                          Med/Surg
# 14   37652315.0                                    Neuro Stepdown
# 15   38228591.0                               Hematology/Oncology
# 16   39136387.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 17   39429848.0                Medical Intensive Care Unit (MICU)
# 18   39544317.0                                          Medicine
# 19   39793139.0                                          Med/Surg
#
# 0                             careunit
# 0                            Neurology
# 1   Medical Intensive Care Unit (MICU)
# 2                            Neurology
# 3                      Cardiac Surgery
# 4                             Medicine
# 5                  Medicine/Cardiology
# 6                             Medicine
# 7                            Neurology
# 8                            Neurology
# 9                             Medicine
# 10    Hematology/Oncology Intermediate
# 11                            Medicine
# 12                           Neurology
# 13                            Vascular
# 14                     Med/Surg/Trauma
# 15                 Medicine/Cardiology
# 16                 Hematology/Oncology
# 17    Hematology/Oncology Intermediate
# 18                            Medicine
# 19                     Med/Surg/Trauma

# %%
target_microbio = target_microbio.groupby('transfer_id')[['pred_microbio','y_microbio']].apply(lambda x: x.mode().iloc[0]).reset_index()

# %%
target_microbio
# Out:
# 0   transfer_id                                     pred_microbio  \
# 0    30281852.0                                          Med/Surg
# 1    30642078.0                                   Med/Surg/Trauma
# 2    30896594.0                                      Med/Surg/GYN
# 3    31077365.0                               Hematology/Oncology
# 4    31983963.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 5    32537286.0                                   Med/Surg/Trauma
# 6    32627049.0                                   Med/Surg/Trauma
# 7    32787491.0                                          Medicine
# 8    32832189.0                                   Med/Surg/Trauma
# 9    33082827.0                                          Med/Surg
# 10   34170353.0                                        Transplant
# 11   34302052.0                Medical Intensive Care Unit (MICU)
# 12   34372637.0                                          Medicine
# 13   34953924.0                                   Cardiac Surgery
# 14   34976513.0                                   Med/Surg/Trauma
# 15   35065627.0                                          Medicine
# 16   35186527.0                  Hematology/Oncology Intermediate
# 17   35258379.0                                          Medicine
# 18   36412172.0      Cardiac Vascular Intensive Care Unit (CVICU)
# 19   37509207.0                                          Medicine
# 20   37665491.0                                          Medicine
# 21   37921160.0                                   Med/Surg/Trauma
# 22   38369052.0                               Trauma SICU (TSICU)
# 23   38430513.0                                   Med/Surg/Trauma
# 24   39136387.0                                   Med/Surg/Trauma
# 25   39429848.0                                          Medicine
# 26   39544317.0                                   Cardiac Surgery
# 27   39793139.0                                   Med/Surg/Trauma
#
# 0                                     y_microbio
# 0                                      Neurology
# 1                                       Medicine
# 2             Medical Intensive Care Unit (MICU)
# 3             Medical Intensive Care Unit (MICU)
# 4                                           PACU
# 5                                       Medicine
# 6                            Medicine/Cardiology
# 7                                       Medicine
# 8                                      Neurology
# 9                                Cardiac Surgery
# 10                           Trauma SICU (TSICU)
# 11                                     Neurology
# 12                                      Medicine
# 13                               Cardiac Surgery
# 14                           Hematology/Oncology
# 15           Surgical Intensive Care Unit (SICU)
# 16              Hematology/Oncology Intermediate
# 17  Cardiac Vascular Intensive Care Unit (CVICU)
# 18                                      Medicine
# 19                                      Vascular
# 20                                      Medicine
# 21                               Med/Surg/Trauma
# 22                              Discharge Lounge
# 23            Medical Intensive Care Unit (MICU)
# 24                           Hematology/Oncology
# 25              Hematology/Oncology Intermediate
# 26                                      Medicine
# 27                               Med/Surg/Trauma

# %%
target_ingredient = target_ingredient.groupby('transfer_id')[['pred_ingredient','y_ingredient']].apply(lambda x: x.mode().iloc[0]).reset_index()

# %%
target_ingredient
# Out:
# 0   transfer_id      pred_ingredient  \
# 0    30281852.0             Medicine
# 1    30896594.0             Medicine
# 2    31026953.0  Medicine/Cardiology
# 3    32051325.0      Cardiac Surgery
# 4    32537286.0             Medicine
# 5    32627049.0             Medicine
# 6    32787491.0             Medicine
# 7    32832189.0             Medicine
# 8    32932646.0             Medicine
# 9    33281088.0      Cardiac Surgery
# 10   34302052.0             Medicine
# 11   34372637.0             Medicine
# 12   35186527.0  Medicine/Cardiology
# 13   36412172.0         Med/Surg/GYN
# 14   37348935.0  Medicine/Cardiology
# 15   37509207.0             Medicine
# 16   37652315.0             Medicine
# 17   38228591.0             Medicine
# 18   39136387.0             Medicine
# 19   39429848.0  Medicine/Cardiology
# 20   39544317.0             Medicine
# 21   39793139.0             Medicine
#
# 0                                       y_ingredient
# 0                                          Neurology
# 1                 Medical Intensive Care Unit (MICU)
# 2                                          Neurology
# 3                                    Cardiac Surgery
# 4                                           Medicine
# 5                                Medicine/Cardiology
# 6                                           Medicine
# 7                                          Neurology
# 8                                           Vascular
# 9   Medical/Surgical Intensive Care Unit (MICU/SICU)
# 10                                         Neurology
# 11                                          Medicine
# 12                  Hematology/Oncology Intermediate
# 13                                          Medicine
# 14                                         Neurology
# 15                                          Vascular
# 16                                   Med/Surg/Trauma
# 17                               Medicine/Cardiology
# 18                               Hematology/Oncology
# 19                  Hematology/Oncology Intermediate
# 20                                          Medicine
# 21                                   Med/Surg/Trauma

# %%
target_prescriptions = target_prescriptions.groupby('transfer_id')[['pred_prescriptions','y_prescriptions']].apply(lambda x: x.mode().iloc[0]).reset_index()

# %%
target_prescriptions
# Out:
# 0   transfer_id                            pred_prescriptions  \
# 0    30145190.0  Cardiac Vascular Intensive Care Unit (CVICU)
# 1    30185783.0                               Cardiac Surgery
# 2    30265082.0                           Hematology/Oncology
# 3    30281852.0                                      Medicine
# 4    30642078.0                               Cardiac Surgery
# ..          ...                                           ...
# 67   39544317.0                                      Med/Surg
# 68   39641848.0                                      Medicine
# 69   39670756.0            Medical Intensive Care Unit (MICU)
# 70   39764235.0                                      Med/Surg
# 71   39793139.0                               Cardiac Surgery
#
# 0        y_prescriptions
# 0              Neurology
# 1               Medicine
# 2    Hematology/Oncology
# 3              Neurology
# 4               Medicine
# ..                   ...
# 67              Medicine
# 68            Transplant
# 69   Hematology/Oncology
# 70  Emergency Department
# 71       Med/Surg/Trauma
#
# [72 rows x 3 columns]

# %%
target_emar = target_emar.groupby('transfer_id')[['pred_emar','y_emar']].apply(lambda x: x.mode().iloc[0]).reset_index()

# %%
target_emar
# Out:
# 0   transfer_id                                         pred_emar  \
# 0    30145190.0                          Coronary Care Unit (CCU)
# 1    30145612.0                                          Medicine
# 2    30185783.0                                      Med/Surg/GYN
# 3    30458338.0                                          Medicine
# 4    30619804.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 5    30642078.0                               Hematology/Oncology
# 6    30744153.0                                          Medicine
# 7    31043383.0                               Trauma SICU (TSICU)
# 8    31077365.0                               Hematology/Oncology
# 9    31306648.0                               Medicine/Cardiology
# 10   31320729.0                               Medicine/Cardiology
# 11   31373193.0                                              PACU
# 12   31503280.0                               Hematology/Oncology
# 13   31582912.0                                          Medicine
# 14   31594060.0                               Hematology/Oncology
# 15   31715741.0                  Medicine/Cardiology Intermediate
# 16   31983963.0                               Medicine/Cardiology
# 17   32051325.0                                   Cardiac Surgery
# 18   32131502.0                               Medicine/Cardiology
# 19   32537286.0                                      Med/Surg/GYN
# 20   32537287.0                                          Medicine
# 21   32554129.0                                   Cardiac Surgery
# 22   32660091.0                               Hematology/Oncology
# 23   32732194.0                                          Medicine
# 24   32832189.0                                          Medicine
# 25   32932646.0                                   Med/Surg/Trauma
# 26   33281088.0                                   Cardiac Surgery
# 27   33747001.0                               Hematology/Oncology
# 28   33915179.0                               Medicine/Cardiology
# 29   33994907.0                                          Vascular
# 30   34107647.0                                          Medicine
# 31   34170353.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 32   34392585.0                                   Cardiac Surgery
# 33   34503142.0                                          Med/Surg
# 34   35044342.0                               Medicine/Cardiology
# 35   35186527.0                               Medicine/Cardiology
# 36   35485831.0                  Emergency Department Observation
# 37   35509340.0                                              PACU
# 38   35727289.0                                          Medicine
# 39   35921271.0   Neuro Surgical Intensive Care Unit (Neuro SICU)
# 40   36059427.0                Medical Intensive Care Unit (MICU)
# 41   36190790.0                                          Medicine
# 42   36974713.0                                          Medicine
# 43   37348935.0                Medical Intensive Care Unit (MICU)
# 44   37460777.0                               Medicine/Cardiology
# 45   37652315.0                                   Cardiac Surgery
# 46   37738145.0                               Medicine/Cardiology
# 47   38228591.0                                         Neurology
# 48   38430513.0                                        Transplant
# 49   38598607.0                                          Vascular
# 50   39136387.0                               Medicine/Cardiology
# 51   39257822.0                                   Cardiac Surgery
# 52   39429848.0                                          Medicine
# 53   39641848.0                                          Medicine
# 54   39739186.0                                              PACU
#
# 0                                             y_emar
# 0                                          Neurology
# 1                                           Medicine
# 2                                           Medicine
# 3                   Hematology/Oncology Intermediate
# 4                                           Med/Surg
# 5                                           Medicine
# 6                                          Neurology
# 7                                Medicine/Cardiology
# 8                 Medical Intensive Care Unit (MICU)
# 9                                           Medicine
# 10                  Emergency Department Observation
# 11                                    Surgery/Trauma
# 12                                          Med/Surg
# 13                                         Neurology
# 14                  Emergency Department Observation
# 15                                          Medicine
# 16                                              PACU
# 17                                   Cardiac Surgery
# 18                                          Vascular
# 19                                          Medicine
# 20                              Emergency Department
# 21                                Neuro Intermediate
# 22                  Emergency Department Observation
# 23                                              PACU
# 24                                         Neurology
# 25                                          Vascular
# 26  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 27                                              PACU
# 28                                           Unknown
# 29                  Hematology/Oncology Intermediate
# 30  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 31                               Trauma SICU (TSICU)
# 32                                   Med/Surg/Trauma
# 33                  Emergency Department Observation
# 34  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 35                  Hematology/Oncology Intermediate
# 36                  Emergency Department Observation
# 37                                        Transplant
# 38  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 39                                          Medicine
# 40                          Coronary Care Unit (CCU)
# 41                                         Neurology
# 42                                      Med/Surg/GYN
# 43                                         Neurology
# 44                                          Med/Surg
# 45                                   Med/Surg/Trauma
# 46                                          Vascular
# 47                               Medicine/Cardiology
# 48                Medical Intensive Care Unit (MICU)
# 49                  Emergency Department Observation
# 50                               Hematology/Oncology
# 51                                          Medicine
# 52                  Hematology/Oncology Intermediate
# 53                                        Transplant
# 54                                        Transplant

# %%
# Merge on transfer_id
merged_df = pd.merge(target_input, target_procedure_events, on='transfer_id', how='outer')
merged_df = pd.merge(merged_df, target_microbio, on='transfer_id', how='outer')
merged_df = pd.merge(merged_df, target_ingredient, on='transfer_id', how='outer')
merged_df = pd.merge(merged_df, target_prescriptions, on='transfer_id', how='outer')
merged_df = pd.merge(merged_df, target_emar, on='transfer_id', how='outer')
merged_df
# Out:
# 0   transfer_id                                        pred_input  \
# 0    30281852.0                                   Med/Surg/Trauma
# 1    30896594.0                                          Medicine
# 2    31026953.0      Cardiac Vascular Intensive Care Unit (CVICU)
# 3    32051325.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 4    32537286.0                Medical Intensive Care Unit (MICU)
# ..          ...                                               ...
# 95   36190790.0                                               NaN
# 96   36974713.0                                               NaN
# 97   38598607.0                                               NaN
# 98   39257822.0                                               NaN
# 99   39739186.0                                               NaN
#
# 0                              y_input  \
# 0                            Neurology
# 1   Medical Intensive Care Unit (MICU)
# 2                            Neurology
# 3                      Cardiac Surgery
# 4                             Medicine
# ..                                 ...
# 95                                 NaN
# 96                                 NaN
# 97                                 NaN
# 98                                 NaN
# 99                                 NaN
#
# 0                              pred_procedure_events  \
# 0                                    Med/Surg/Trauma
# 1                                           Medicine
# 2                                    Med/Surg/Trauma
# 3   Medical/Surgical Intensive Care Unit (MICU/SICU)
# 4                 Medical Intensive Care Unit (MICU)
# ..                                               ...
# 95                                               NaN
# 96                                               NaN
# 97                                               NaN
# 98                                               NaN
# 99                                               NaN
#
# 0                   y_procedure_events    pred_microbio  \
# 0                            Neurology         Med/Surg
# 1   Medical Intensive Care Unit (MICU)     Med/Surg/GYN
# 2                            Neurology              NaN
# 3                      Cardiac Surgery              NaN
# 4                             Medicine  Med/Surg/Trauma
# ..                                 ...              ...
# 95                                 NaN              NaN
# 96                                 NaN              NaN
# 97                                 NaN              NaN
# 98                                 NaN              NaN
# 99                                 NaN              NaN
#
# 0                           y_microbio      pred_ingredient  \
# 0                            Neurology             Medicine
# 1   Medical Intensive Care Unit (MICU)             Medicine
# 2                                  NaN  Medicine/Cardiology
# 3                                  NaN      Cardiac Surgery
# 4                             Medicine             Medicine
# ..                                 ...                  ...
# 95                                 NaN                  NaN
# 96                                 NaN                  NaN
# 97                                 NaN                  NaN
# 98                                 NaN                  NaN
# 99                                 NaN                  NaN
#
# 0                         y_ingredient pred_prescriptions  \
# 0                            Neurology           Medicine
# 1   Medical Intensive Care Unit (MICU)           Medicine
# 2                            Neurology    Med/Surg/Trauma
# 3                      Cardiac Surgery    Cardiac Surgery
# 4                             Medicine    Cardiac Surgery
# ..                                 ...                ...
# 95                                 NaN                NaN
# 96                                 NaN                NaN
# 97                                 NaN                NaN
# 98                                 NaN                NaN
# 99                                 NaN                NaN
#
# 0                      y_prescriptions        pred_emar  \
# 0                            Neurology              NaN
# 1   Medical Intensive Care Unit (MICU)              NaN
# 2                            Neurology              NaN
# 3                      Cardiac Surgery  Cardiac Surgery
# 4                             Medicine     Med/Surg/GYN
# ..                                 ...              ...
# 95                                 NaN         Medicine
# 96                                 NaN         Medicine
# 97                                 NaN         Vascular
# 98                                 NaN  Cardiac Surgery
# 99                                 NaN             PACU
#
# 0                             y_emar
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                    Cardiac Surgery
# 4                           Medicine
# ..                               ...
# 95                         Neurology
# 96                      Med/Surg/GYN
# 97  Emergency Department Observation
# 98                          Medicine
# 99                        Transplant
#
# [100 rows x 13 columns]

# %%
def mode_without_nan(row):
    return row.mode() if not row.isnull().all() else np.nan

# %%
# Select columns that begin with 'y_'
y_columns = merged_df.filter(like='y_')

# Calculate mode across rows, ignoring NaN values
merged_df['careunit'] = y_columns.apply(mode_without_nan, axis=1)

# %%
merged_df
# Out:
# 0   transfer_id                                        pred_input  \
# 0    30281852.0                                   Med/Surg/Trauma
# 1    30896594.0                                          Medicine
# 2    31026953.0      Cardiac Vascular Intensive Care Unit (CVICU)
# 3    32051325.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 4    32537286.0                Medical Intensive Care Unit (MICU)
# ..          ...                                               ...
# 95   36190790.0                                               NaN
# 96   36974713.0                                               NaN
# 97   38598607.0                                               NaN
# 98   39257822.0                                               NaN
# 99   39739186.0                                               NaN
#
# 0                              y_input  \
# 0                            Neurology
# 1   Medical Intensive Care Unit (MICU)
# 2                            Neurology
# 3                      Cardiac Surgery
# 4                             Medicine
# ..                                 ...
# 95                                 NaN
# 96                                 NaN
# 97                                 NaN
# 98                                 NaN
# 99                                 NaN
#
# 0                              pred_procedure_events  \
# 0                                    Med/Surg/Trauma
# 1                                           Medicine
# 2                                    Med/Surg/Trauma
# 3   Medical/Surgical Intensive Care Unit (MICU/SICU)
# 4                 Medical Intensive Care Unit (MICU)
# ..                                               ...
# 95                                               NaN
# 96                                               NaN
# 97                                               NaN
# 98                                               NaN
# 99                                               NaN
#
# 0                   y_procedure_events    pred_microbio  \
# 0                            Neurology         Med/Surg
# 1   Medical Intensive Care Unit (MICU)     Med/Surg/GYN
# 2                            Neurology              NaN
# 3                      Cardiac Surgery              NaN
# 4                             Medicine  Med/Surg/Trauma
# ..                                 ...              ...
# 95                                 NaN              NaN
# 96                                 NaN              NaN
# 97                                 NaN              NaN
# 98                                 NaN              NaN
# 99                                 NaN              NaN
#
# 0                           y_microbio      pred_ingredient  \
# 0                            Neurology             Medicine
# 1   Medical Intensive Care Unit (MICU)             Medicine
# 2                                  NaN  Medicine/Cardiology
# 3                                  NaN      Cardiac Surgery
# 4                             Medicine             Medicine
# ..                                 ...                  ...
# 95                                 NaN                  NaN
# 96                                 NaN                  NaN
# 97                                 NaN                  NaN
# 98                                 NaN                  NaN
# 99                                 NaN                  NaN
#
# 0                         y_ingredient pred_prescriptions  \
# 0                            Neurology           Medicine
# 1   Medical Intensive Care Unit (MICU)           Medicine
# 2                            Neurology    Med/Surg/Trauma
# 3                      Cardiac Surgery    Cardiac Surgery
# 4                             Medicine    Cardiac Surgery
# ..                                 ...                ...
# 95                                 NaN                NaN
# 96                                 NaN                NaN
# 97                                 NaN                NaN
# 98                                 NaN                NaN
# 99                                 NaN                NaN
#
# 0                      y_prescriptions        pred_emar  \
# 0                            Neurology              NaN
# 1   Medical Intensive Care Unit (MICU)              NaN
# 2                            Neurology              NaN
# 3                      Cardiac Surgery  Cardiac Surgery
# 4                             Medicine     Med/Surg/GYN
# ..                                 ...              ...
# 95                                 NaN         Medicine
# 96                                 NaN         Medicine
# 97                                 NaN         Vascular
# 98                                 NaN  Cardiac Surgery
# 99                                 NaN             PACU
#
# 0                             y_emar                            careunit
# 0                                NaN                           Neurology
# 1                                NaN  Medical Intensive Care Unit (MICU)
# 2                                NaN                           Neurology
# 3                    Cardiac Surgery                     Cardiac Surgery
# 4                           Medicine                            Medicine
# ..                               ...                                 ...
# 95                         Neurology                           Neurology
# 96                      Med/Surg/GYN                        Med/Surg/GYN
# 97  Emergency Department Observation    Emergency Department Observation
# 98                          Medicine                            Medicine
# 99                        Transplant                          Transplant
#
# [100 rows x 14 columns]

# %%
y_columns.columns
# Out:
# Index(['y_input', 'y_procedure_events', 'y_microbio', 'y_ingredient',
#        'y_prescriptions', 'y_emar'],
#       dtype='object', name=0)

# %%
merged_df.drop(columns=y_columns.columns, inplace=True)

# %%
merged_df
# Out:
# 0   transfer_id                                        pred_input  \
# 0    30281852.0                                   Med/Surg/Trauma
# 1    30896594.0                                          Medicine
# 2    31026953.0      Cardiac Vascular Intensive Care Unit (CVICU)
# 3    32051325.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 4    32537286.0                Medical Intensive Care Unit (MICU)
# ..          ...                                               ...
# 95   36190790.0                                               NaN
# 96   36974713.0                                               NaN
# 97   38598607.0                                               NaN
# 98   39257822.0                                               NaN
# 99   39739186.0                                               NaN
#
# 0                              pred_procedure_events    pred_microbio  \
# 0                                    Med/Surg/Trauma         Med/Surg
# 1                                           Medicine     Med/Surg/GYN
# 2                                    Med/Surg/Trauma              NaN
# 3   Medical/Surgical Intensive Care Unit (MICU/SICU)              NaN
# 4                 Medical Intensive Care Unit (MICU)  Med/Surg/Trauma
# ..                                               ...              ...
# 95                                               NaN              NaN
# 96                                               NaN              NaN
# 97                                               NaN              NaN
# 98                                               NaN              NaN
# 99                                               NaN              NaN
#
# 0       pred_ingredient pred_prescriptions        pred_emar  \
# 0              Medicine           Medicine              NaN
# 1              Medicine           Medicine              NaN
# 2   Medicine/Cardiology    Med/Surg/Trauma              NaN
# 3       Cardiac Surgery    Cardiac Surgery  Cardiac Surgery
# 4              Medicine    Cardiac Surgery     Med/Surg/GYN
# ..                  ...                ...              ...
# 95                  NaN                NaN         Medicine
# 96                  NaN                NaN         Medicine
# 97                  NaN                NaN         Vascular
# 98                  NaN                NaN  Cardiac Surgery
# 99                  NaN                NaN             PACU
#
# 0                             careunit
# 0                            Neurology
# 1   Medical Intensive Care Unit (MICU)
# 2                            Neurology
# 3                      Cardiac Surgery
# 4                             Medicine
# ..                                 ...
# 95                           Neurology
# 96                        Med/Surg/GYN
# 97    Emergency Department Observation
# 98                            Medicine
# 99                          Transplant
#
# [100 rows x 8 columns]

# %%
def mode_without_nan(row):
    return row.mode()[0] if not row.isnull().all() else np.nan

# %%
# Add a new column containing the mode of values across rows, ignoring NaN values
merged_df['Vote'] = merged_df.drop(columns=['transfer_id','careunit']).apply(mode_without_nan, axis=1)

# %%
merged_df
# Out:
# 0   transfer_id                                        pred_input  \
# 0    30281852.0                                   Med/Surg/Trauma
# 1    30896594.0                                          Medicine
# 2    31026953.0      Cardiac Vascular Intensive Care Unit (CVICU)
# 3    32051325.0  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 4    32537286.0                Medical Intensive Care Unit (MICU)
# ..          ...                                               ...
# 95   36190790.0                                               NaN
# 96   36974713.0                                               NaN
# 97   38598607.0                                               NaN
# 98   39257822.0                                               NaN
# 99   39739186.0                                               NaN
#
# 0                              pred_procedure_events    pred_microbio  \
# 0                                    Med/Surg/Trauma         Med/Surg
# 1                                           Medicine     Med/Surg/GYN
# 2                                    Med/Surg/Trauma              NaN
# 3   Medical/Surgical Intensive Care Unit (MICU/SICU)              NaN
# 4                 Medical Intensive Care Unit (MICU)  Med/Surg/Trauma
# ..                                               ...              ...
# 95                                               NaN              NaN
# 96                                               NaN              NaN
# 97                                               NaN              NaN
# 98                                               NaN              NaN
# 99                                               NaN              NaN
#
# 0       pred_ingredient pred_prescriptions        pred_emar  \
# 0              Medicine           Medicine              NaN
# 1              Medicine           Medicine              NaN
# 2   Medicine/Cardiology    Med/Surg/Trauma              NaN
# 3       Cardiac Surgery    Cardiac Surgery  Cardiac Surgery
# 4              Medicine    Cardiac Surgery     Med/Surg/GYN
# ..                  ...                ...              ...
# 95                  NaN                NaN         Medicine
# 96                  NaN                NaN         Medicine
# 97                  NaN                NaN         Vascular
# 98                  NaN                NaN  Cardiac Surgery
# 99                  NaN                NaN             PACU
#
# 0                             careunit                                Vote
# 0                            Neurology                     Med/Surg/Trauma
# 1   Medical Intensive Care Unit (MICU)                            Medicine
# 2                            Neurology                     Med/Surg/Trauma
# 3                      Cardiac Surgery                     Cardiac Surgery
# 4                             Medicine  Medical Intensive Care Unit (MICU)
# ..                                 ...                                 ...
# 95                           Neurology                            Medicine
# 96                        Med/Surg/GYN                            Medicine
# 97    Emergency Department Observation                            Vascular
# 98                            Medicine                     Cardiac Surgery
# 99                          Transplant                                PACU
#
# [100 rows x 9 columns]

# %%
# Evaluate the model
accuracy = accuracy_score(merged_df['careunit'], merged_df['Vote'])
print("Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(merged_df['careunit'], merged_df['Vote'], zero_division=0))
# Out:
# Accuracy: 0.11
# Classification Report:
#                                                   precision    recall  f1-score   support
#
#                                  Cardiac Surgery       0.18      0.60      0.27         5
#     Cardiac Vascular Intensive Care Unit (CVICU)       0.00      0.00      0.00         3
#                         Coronary Care Unit (CCU)       0.00      0.00      0.00         1
#                                 Discharge Lounge       0.00      0.00      0.00         2
#                             Emergency Department       0.00      0.00      0.00         7
#                 Emergency Department Observation       1.00      0.17      0.29         6
#                              Hematology/Oncology       0.09      0.20      0.13         5
#                 Hematology/Oncology Intermediate       0.00      0.00      0.00         4
#                                         Med/Surg       0.25      0.29      0.27         7
#                                     Med/Surg/GYN       0.00      0.00      0.00         2
#                                  Med/Surg/Trauma       0.00      0.00      0.00         4
#               Medical Intensive Care Unit (MICU)       0.00      0.00      0.00         3
# Medical/Surgical Intensive Care Unit (MICU/SICU)       0.00      0.00      0.00         5
#                                         Medicine       0.16      0.31      0.21        13
#                              Medicine/Cardiology       0.00      0.00      0.00         6
#                 Medicine/Cardiology Intermediate       0.00      0.00      0.00         0
#                               Neuro Intermediate       0.00      0.00      0.00         1
#                                   Neuro Stepdown       0.00      0.00      0.00         0
#                                        Neurology       0.00      0.00      0.00         9
#                                             PACU       0.00      0.00      0.00         3
#                                       Psychiatry       0.00      0.00      0.00         1
#                                   Surgery/Trauma       0.00      0.00      0.00         1
#              Surgical Intensive Care Unit (SICU)       0.00      0.00      0.00         1
#                                       Transplant       0.00      0.00      0.00         3
#                              Trauma SICU (TSICU)       0.00      0.00      0.00         1
#                                          Unknown       0.00      0.00      0.00         1
#                                         Vascular       0.00      0.00      0.00         6
#
#                                         accuracy                           0.11       100
#                                        macro avg       0.06      0.06      0.04       100
#                                     weighted avg       0.11      0.11      0.08       100

# %%
# Should be 183 evaluation transfers
# The missing ones could be transfers that happened in the same day and no other recorded information happened between that 
# time (so a prediction cannot be made)
